# %% [markdown]
# Assignment 00

# %% [markdown]
# This is the screenshot
# ![Screen Shot 2025-09-01 at 11.07.29 PM.png](attachment:e18890e8-dd68-4f98-8996-ad49105f2a2d.png)

# %% [markdown]
# https://github.com/yelebe-desta/machine_learning_fall2025

# %% [markdown]
# A conda environment is like a separate workspace that keeps all the packages and Python versions for a project in one place. I like that it makes my work more organized since I don’t have to worry about breaking another project when I install something new. It’s also easy to share with others, because they can just recreate the same environment from my setup files and get things running the same way.
#
# Python Part 1
# Jupyter notebook: can mix code with text and visuals.
# Variables act as placeholders for data.
# Operations in python: how to assignment =, basic arithmetic (+, -, *, /)
# Python Part 2
# A concise way to build lists without explicit loops.
# Can combine sequences, apply transformations, and include conditionals.
# Dictionaries: Defined with curly braces {} and useful for storing structured data.
